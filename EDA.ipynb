# %% [markdown]
# This notebook is exploratory data analysis of the different datasets.  We look to see:
#
# - what data is available in each dataset
# - if there are any missing values and/or outliers
# - summary statistics on some of the data

# %%
import pandas as pd

# Set up GCP and AWS bucket APIs
from google.cloud import bigquery
# Construct a BigQuery client object.
client = bigquery.Client()

# %% [markdown]
# # US Census ACS data
#
# First we see what's available in ACS and load one file.

# %% [markdown]
# # Set up BigQuery column info queries and DB/Table names

# %%
# ACS US census data
ACS_DB = '`bigquery-public-data`.census_bureau_acs'
ACS_TABLE = 'zip_codes_2017_5yr'

# project sunroof
PSR_DB = '`bigquery-public-data`.sunroof_solar'
PSR_TABLE = 'solar_potential_by_postal_code'

# This gives us columns:
# ['table_catalog', 'table_schema', 'table_name', 'column_name',
# 'field_path', 'data_type', 'description']
column_descr_query = """SELECT *
FROM {}.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS
WHERE table_name="{}";
"""

# we don't get description, but get IS_NULLABLE from this
column_details_query = """SELECT *
FROM {}.INFORMATION_SCHEMA.COLUMNS
WHERE table_name="{}";
"""

# %% [markdown]
# # Examine ACS schema
#
# GBQ reference for getting metadata on tables:

# %%
query = column_descr_query.format(ACS_DB, ACS_TABLE)

df = pd.read_gbq(query)
# Out:
# Downloading: 100%|██████████| 252/252 [00:00<00:00, 1373.85rows/s]

# %%
# show all rows
pd.set_option('display.max_rows', None)

# %%
df[['column_name', 'data_type', 'description']]
# Out:
#                                            column_name data_type  \
# 0                                               geo_id    STRING
# 1                                 nonfamily_households   FLOAT64
# 2                                    family_households   FLOAT64
# 3                          median_year_structure_built   FLOAT64
# 4                             rent_burden_not_computed   FLOAT64
# 5                                 rent_over_50_percent   FLOAT64
# 6                                rent_40_to_50_percent   FLOAT64
# 7                                rent_35_to_40_percent   FLOAT64
# 8                                rent_30_to_35_percent   FLOAT64
# 9                                rent_25_to_30_percent   FLOAT64
# 10                               rent_20_to_25_percent   FLOAT64
# 11                               rent_15_to_20_percent   FLOAT64
# 12                               rent_10_to_15_percent   FLOAT64
# 13                               rent_under_10_percent   FLOAT64
# 14                                           total_pop   FLOAT64
# 15                                            male_pop   FLOAT64
# 16                                          female_pop   FLOAT64
# 17                                          median_age   FLOAT64
# 18                                           white_pop   FLOAT64
# 19                                           black_pop   FLOAT64
# 20                                           asian_pop   FLOAT64
# 21                                        hispanic_pop   FLOAT64
# 22                                      amerindian_pop   FLOAT64
# 23                                      other_race_pop   FLOAT64
# 24                               two_or_more_races_pop   FLOAT64
# 25                                    not_hispanic_pop   FLOAT64
# 26                  commuters_by_public_transportation   FLOAT64
# 27                                          households   FLOAT64
# 28                                       median_income   FLOAT64
# 29                                   income_per_capita   FLOAT64
# 30                                       housing_units   FLOAT64
# 31                                vacant_housing_units   FLOAT64
# 32                       vacant_housing_units_for_rent   FLOAT64
# 33                       vacant_housing_units_for_sale   FLOAT64
# 34                                         median_rent   FLOAT64
# 35                        percent_income_spent_on_rent   FLOAT64
# 36                        owner_occupied_housing_units   FLOAT64
# 37                        million_dollar_housing_units   FLOAT64
# 38                             mortgaged_housing_units   FLOAT64
# 39                        families_with_young_children   FLOAT64
# 40             two_parent_families_with_young_children   FLOAT64
# 41   two_parents_in_labor_force_families_with_young...   FLOAT64
# 42   two_parents_father_in_labor_force_families_wit...   FLOAT64
# 43   two_parents_mother_in_labor_force_families_wit...   FLOAT64
# 44   two_parents_not_in_labor_force_families_with_y...   FLOAT64
# 45             one_parent_families_with_young_children   FLOAT64
# 46      father_one_parent_families_with_young_children   FLOAT64
# 47   father_in_labor_force_one_parent_families_with...   FLOAT64
# 48                                  commute_10_14_mins   FLOAT64
# 49                                  commute_15_19_mins   FLOAT64
# 50                                  commute_20_24_mins   FLOAT64
# 51                                  commute_25_29_mins   FLOAT64
# 52                                  commute_30_34_mins   FLOAT64
# 53                                  commute_45_59_mins   FLOAT64
# 54                       aggregate_travel_time_to_work   FLOAT64
# 55                                   income_less_10000   FLOAT64
# 56                                  income_10000_14999   FLOAT64
# 57                                  income_15000_19999   FLOAT64
# 58                                  income_20000_24999   FLOAT64
# 59                                  income_25000_29999   FLOAT64
# 60                                  income_30000_34999   FLOAT64
# 61                                  income_35000_39999   FLOAT64
# 62                                  income_40000_44999   FLOAT64
# 63                                  income_45000_49999   FLOAT64
# 64                                  income_50000_59999   FLOAT64
# 65                                  income_60000_74999   FLOAT64
# 66                                  income_75000_99999   FLOAT64
# 67                                income_100000_124999   FLOAT64
# 68                                income_125000_149999   FLOAT64
# 69                                income_150000_199999   FLOAT64
# 70                               income_200000_or_more   FLOAT64
# 71   renter_occupied_housing_units_paying_cash_medi...   FLOAT64
# 72   owner_occupied_housing_units_lower_value_quartile   FLOAT64
# 73           owner_occupied_housing_units_median_value   FLOAT64
# 74   owner_occupied_housing_units_upper_value_quartile   FLOAT64
# 75                                  married_households   FLOAT64
# 76                              occupied_housing_units   FLOAT64
# 77                       housing_units_renter_occupied   FLOAT64
# 78                          dwellings_1_units_detached   FLOAT64
# 79                          dwellings_1_units_attached   FLOAT64
# 80                                   dwellings_2_units   FLOAT64
# 81                              dwellings_3_to_4_units   FLOAT64
# 82                              dwellings_5_to_9_units   FLOAT64
# 83                            dwellings_10_to_19_units   FLOAT64
# 84                            dwellings_20_to_49_units   FLOAT64
# 85                          dwellings_50_or_more_units   FLOAT64
# 86                                        mobile_homes   FLOAT64
# 87                         housing_built_2005_or_later   FLOAT64
# 88                          housing_built_2000_to_2004   FLOAT64
# 89                       housing_built_1939_or_earlier   FLOAT64
# 90                                        male_under_5   FLOAT64
# 91                                         male_5_to_9   FLOAT64
# 92                                       male_10_to_14   FLOAT64
# 93                                       male_15_to_17   FLOAT64
# 94                                       male_18_to_19   FLOAT64
# 95                                             male_20   FLOAT64
# 96                                             male_21   FLOAT64
# 97                                       male_22_to_24   FLOAT64
# 98                                       male_25_to_29   FLOAT64
# 99                                       male_30_to_34   FLOAT64
# 100                                      male_35_to_39   FLOAT64
# 101                                      male_40_to_44   FLOAT64
# 102                                      male_45_to_49   FLOAT64
# 103                                      male_50_to_54   FLOAT64
# 104                                      male_55_to_59   FLOAT64
# 105                                         male_60_61   FLOAT64
# 106                                         male_62_64   FLOAT64
# 107                                      male_65_to_66   FLOAT64
# 108                                      male_67_to_69   FLOAT64
# 109                                      male_70_to_74   FLOAT64
# 110                                      male_75_to_79   FLOAT64
# 111                                      male_80_to_84   FLOAT64
# 112                                   male_85_and_over   FLOAT64
# 113                                     female_under_5   FLOAT64
# 114                                      female_5_to_9   FLOAT64
# 115                                    female_10_to_14   FLOAT64
# 116                                    female_15_to_17   FLOAT64
# 117                                    female_18_to_19   FLOAT64
# 118                                          female_20   FLOAT64
# 119                                          female_21   FLOAT64
# 120                                    female_22_to_24   FLOAT64
# 121                                    female_25_to_29   FLOAT64
# 122                                    female_30_to_34   FLOAT64
# 123                                    female_35_to_39   FLOAT64
# 124                                    female_40_to_44   FLOAT64
# 125                                    female_45_to_49   FLOAT64
# 126                                    female_50_to_54   FLOAT64
# 127                                    female_55_to_59   FLOAT64
# 128                                    female_60_to_61   FLOAT64
# 129                                    female_62_to_64   FLOAT64
# 130                                    female_65_to_66   FLOAT64
# 131                                    female_67_to_69   FLOAT64
# 132                                    female_70_to_74   FLOAT64
# 133                                    female_75_to_79   FLOAT64
# 134                                    female_80_to_84   FLOAT64
# 135                                 female_85_and_over   FLOAT64
# 136                           white_including_hispanic   FLOAT64
# 137                           black_including_hispanic   FLOAT64
# 138                      amerindian_including_hispanic   FLOAT64
# 139                           asian_including_hispanic   FLOAT64
# 140                                   commute_5_9_mins   FLOAT64
# 141                                 commute_35_39_mins   FLOAT64
# 142                                 commute_40_44_mins   FLOAT64
# 143                                 commute_60_89_mins   FLOAT64
# 144                               commute_90_more_mins   FLOAT64
# 145                       households_retirement_income   FLOAT64
# 146                                       armed_forces   FLOAT64
# 147                               civilian_labor_force   FLOAT64
# 148                                       employed_pop   FLOAT64
# 149                                     unemployed_pop   FLOAT64
# 150                                 not_in_labor_force   FLOAT64
# 151                                        pop_16_over   FLOAT64
# 152                                 pop_in_labor_force   FLOAT64
# 153                                   asian_male_45_54   FLOAT64
# 154                                   asian_male_55_64   FLOAT64
# 155                                   black_male_45_54   FLOAT64
# 156                                   black_male_55_64   FLOAT64
# 157                                hispanic_male_45_54   FLOAT64
# 158                                hispanic_male_55_64   FLOAT64
# 159                                   white_male_45_54   FLOAT64
# 160                                   white_male_55_64   FLOAT64
# 161                                 bachelors_degree_2   FLOAT64
# 162                   bachelors_degree_or_higher_25_64   FLOAT64
# 163                                           children   FLOAT64
# 164                       children_in_single_female_hh   FLOAT64
# 165                                   commuters_by_bus   FLOAT64
# 166                         commuters_by_car_truck_van   FLOAT64
# 167                               commuters_by_carpool   FLOAT64
# 168                    commuters_by_subway_or_elevated   FLOAT64
# 169                              commuters_drove_alone   FLOAT64
# 170            different_house_year_ago_different_city   FLOAT64
# 171                 different_house_year_ago_same_city   FLOAT64
# 172  employed_agriculture_forestry_fishing_hunting_...   FLOAT64
# 173  employed_arts_entertainment_recreation_accommo...   FLOAT64
# 174                              employed_construction   FLOAT64
# 175                   employed_education_health_social   FLOAT64
# 176             employed_finance_insurance_real_estate   FLOAT64
# 177                               employed_information   FLOAT64
# 178                             employed_manufacturing   FLOAT64
# 179           employed_other_services_not_public_admin   FLOAT64
# 180                     employed_public_administration   FLOAT64
# 181                              employed_retail_trade   FLOAT64
# 182            employed_science_management_admin_waste   FLOAT64
# 183      employed_transportation_warehousing_utilities   FLOAT64
# 184                           employed_wholesale_trade   FLOAT64
# 185                           female_female_households   FLOAT64
# 186                                     four_more_cars   FLOAT64
# 187                                         gini_index   FLOAT64
# 188                       graduate_professional_degree   FLOAT64
# 189                                     group_quarters   FLOAT64
# 190                          high_school_including_ged   FLOAT64
# 191              households_public_asst_or_food_stamps   FLOAT64
# 192                                   in_grades_1_to_4   FLOAT64
# 193                                   in_grades_5_to_8   FLOAT64
# 194                                  in_grades_9_to_12   FLOAT64
# 195                                          in_school   FLOAT64
# 196                               in_undergrad_college   FLOAT64
# 197                     less_than_high_school_graduate   FLOAT64
# 198                       male_45_64_associates_degree   FLOAT64
# 199                        male_45_64_bachelors_degree   FLOAT64
# 200                         male_45_64_graduate_degree   FLOAT64
# 201                       male_45_64_less_than_9_grade   FLOAT64
# 202                              male_45_64_grade_9_12   FLOAT64
# 203                             male_45_64_high_school   FLOAT64
# 204                            male_45_64_some_college   FLOAT64
# 205                                      male_45_to_64   FLOAT64
# 206                               male_male_households   FLOAT64
# 207              management_business_sci_arts_employed   FLOAT64
# 208                                             no_car   FLOAT64
# 209                                            no_cars   FLOAT64
# 210                                 not_us_citizen_pop   FLOAT64
# 211                         occupation_management_arts   FLOAT64
# 212  occupation_natural_resources_construction_main...   FLOAT64
# 213      occupation_production_transportation_material   FLOAT64
# 214                            occupation_sales_office   FLOAT64
# 215                                occupation_services   FLOAT64
# 216                                            one_car   FLOAT64
# 217                                           two_cars   FLOAT64
# 218                                         three_cars   FLOAT64
# 219                                          pop_25_64   FLOAT64
# 220                      pop_determined_poverty_status   FLOAT64
# 221                         population_1_year_and_over   FLOAT64
# 222                            population_3_years_over   FLOAT64
# 223                                            poverty   FLOAT64
# 224                              sales_office_employed   FLOAT64
# 225                 some_college_and_associates_degree   FLOAT64
# 226                                     walked_to_work   FLOAT64
# 227                                     worked_at_home   FLOAT64
# 228                                workers_16_and_over   FLOAT64
# 229                                  associates_degree   FLOAT64
# 230                                   bachelors_degree   FLOAT64
# 231                                high_school_diploma   FLOAT64
# 232                              less_one_year_college   FLOAT64
# 233                                     masters_degree   FLOAT64
# 234                              one_year_more_college   FLOAT64
# 235                                  pop_25_years_over   FLOAT64
# 236                                 commute_35_44_mins   FLOAT64
# 237                               commute_60_more_mins   FLOAT64
# 238                               commute_less_10_mins   FLOAT64
# 239                                  commuters_16_over   FLOAT64
# 240                                  hispanic_any_race   FLOAT64
# 241                                   pop_5_years_over   FLOAT64
# 242                         speak_only_english_at_home   FLOAT64
# 243                              speak_spanish_at_home   FLOAT64
# 244                  speak_spanish_at_home_low_english   FLOAT64
# 245                                    pop_15_and_over   FLOAT64
# 246                                  pop_never_married   FLOAT64
# 247                                    pop_now_married   FLOAT64
# 248                                      pop_separated   FLOAT64
# 249                                        pop_widowed   FLOAT64
# 250                                       pop_divorced   FLOAT64
# 251                                            do_date    STRING
#
#                                            description
# 0           US Census Zip Code Tabulation Areas Geoids
# 1    Nonfamily Households. A householder living alo...
# 2    Family Households. A family consists of a hous...
# 3    Median Year Structure Built. Median Year Struc...
# 4    Housing units without rent burden computed. Un...
# 5    Housing units spending over 50% income on rent...
# 6    Housing units spending 40 to 49.9% income on r...
# 7    Housing units spending 35 to 39.9% income on r...
# 8    Housing units spending 30 to 34.9% income on r...
# 9    Housing units spending 25 to 29.9% income on r...
# 10   Housing units spending 20 to 24.9% income on r...
# 11   Housing units spending 15 to 19.9% income on r...
# 12   Housing units spending 10 to 14.9% income on r...
# 13   Housing units spending less than 10% on rent. ...
# 14   Total Population. The total number of all peop...
# 15   Male Population. The number of people within e...
# 16   Female Population. The number of people within...
# 17   Median Age. The median age of all people in a ...
# 18   White Population. The number of people identif...
# 19   Black or African American Population. The numb...
# 20   Asian Population. The number of people identif...
# 21   Hispanic Population. The number of people iden...
# 22   American Indian and Alaska Native Population. ...
# 23   Other Race population. The number of people id...
# 24   Two or more races population. The number of pe...
# 25   Population not Hispanic. The number of people ...
# 26   Commuters by Public Transportation. The number...
# 27   Households. A count of the number of household...
# 28   Median Household Income in the past 12 Months....
# 29   Per Capita Income in the past 12 Months. Per c...
# 30   Housing Units. A count of housing units in eac...
# 31   Vacant Housing Units. The count of vacant hous...
# 32   Vacant Housing Units for Rent. The count of va...
# 33   Vacant Housing Units for Sale. The count of va...
# 34   Median Rent. The median contract rent within a...
# 35   Percent of Household Income Spent on Rent. Wit...
# 36                        Owner-occupied Housing Units
# 37   Owner-occupied Housing Units valued at $1,000,...
# 38   Owner-occupied Housing Units with a Mortgage. ...
# 39   Families with young children (under 6 years of...
# 40   Two-parent families with young children (under...
# 41   Two-parent families, both parents in labor for...
# 42   Two-parent families, father only in labor forc...
# 43   Two-parent families, mother only in labor forc...
# 44   Two-parent families, neither parent in labor f...
# 45   One-parent families with young children (under...
# 46   One-parent families, father, with young childr...
# 47   One-parent families, father in labor force, wi...
# 48   Number of workers with a commute between 10 an...
# 49   Number of workers with a commute between 15 an...
# 50   Number of workers with a commute between 20 an...
# 51   Number of workers with a commute between 25 an...
# 52   Number of workers with a commute between 30 an...
# 53   Number of workers with a commute between 45 an...
# 54   Aggregate travel time to work. The total numbe...
# 55   Households with income less than $10,000. The ...
# 56   Households with income of $10,000 to $14,999. ...
# 57   Households with income of $15,000 to $19,999. ...
# 58   Households with income of $20,000 to $24,999. ...
# 59   Households with income of $25,000 to $29,999. ...
# 60   Households with income of $30,000 to $34,999. ...
# 61   Households with income of $35,000 to $39,999. ...
# 62   Households with income of $40,000 to $44,999. ...
# 63   Households with income of $45,000 to $49,999. ...
# 64   Households with income of $50,000 to $59,999. ...
# 65   Households with income of $60,000 to $74,999. ...
# 66   Households with income of $75,000 to $99,999. ...
# 67   Households with income of $100,000 to $124,999...
# 68   Households with income of $125,000 to $149,999...
# 69   Households with income of $150,000 to $199,999...
# 70   Households with income of $200,000 Or More. Th...
# 71   Renter-Occupied Housing Units Paying Cash Rent...
# 72   Owner-Occupied Housing Units Lower Value Quartile
# 73   Owner-Occupied Housing Units Median Value. The...
# 74   Owner-Occupied Housing Units Upper Value Quartile
# 75   Married households. People in formal marriages...
# 76   Occupied housing units. A housing unit is clas...
# 77   Renter occupied housing units. All occupied un...
# 78   Single-family (one unit) detached dwellings. T...
# 79   Single-family (one unit) attached dwellings. T...
# 80                     Two-family (two unit) dwellings
# 81         Multifamily dwellings with three to 4 units
# 82               Apartment buildings with 5 to 9 units
# 83             Apartment buildings with 10 to 19 units
# 84             Apartment buildings with 20 to 49 units
# 85           Apartment buildings with 50 or more units
# 86   Mobile homes. A manufactured home is defined a...
# 87   Housing units built in 2005 or later. A house,...
# 88   Housing units built between 2000 and 2004. A h...
# 89   Housing units built before 1939. A house, an a...
# 90   Male under 5 years. The male population over t...
# 91   Male age 5 to 9. The male population between t...
# 92   Male age 10 to 14. The male population between...
# 93   Male age 15 to 17. The male population between...
# 94   Male age 18 and 19. The male population betwee...
# 95   Male age 20. The male population with an age o...
# 96   Male age 21. The male population with an age o...
# 97   Male age 22 to 24. The male population between...
# 98   Male age 25 to 29. The male population between...
# 99   Male age 30 to 34. The male population between...
# 100  Male age 35 to 39. The male population between...
# 101  Male age 40 to 44. The male population between...
# 102  Men age 45 to 49. The male population between ...
# 103  Men age 50 to 54. The male population between ...
# 104  Men age 55 to 59. The male population between ...
# 105  Men age 60 to 61. The male population between ...
# 106  Men age 62 to 64. The male population between ...
# 107  Male age 65 to 66. The male population between...
# 108  Male age 67 to 69. The male population between...
# 109  Male age 70 to 74. The male population between...
# 110  Male age 75 to 79. The male population between...
# 111  Male age 80 to 84. The male population between...
# 112  Male age 85 and over. The male population of t...
# 113  Female under 5 years. The female population ov...
# 114  Female age 5 to 9. The female population betwe...
# 115  Female age 10 to 14. The female population bet...
# 116  Female age 15 to 17. The female population bet...
# 117  Female age 18 and 19. The female population be...
# 118  Female age 20. The female population with an a...
# 119  Female age 21. The female population with an a...
# 120  Female age 22 to 24. The female population bet...
# 121  Female age 25 to 29. The female population bet...
# 122  Female age 30 to 34. The female population bet...
# 123  Female age 35 to 39. The female population bet...
# 124  Female age 40 to 44. The female population bet...
# 125  Female age 45 to 49. The female population bet...
# 126  Female age 50 to 54. The female population bet...
# 127  Female age 55 to 59. The female population bet...
# 128  Female age 60 and 61. The female population be...
# 129  Female age 62 to 64. The female population bet...
# 130  Female age 65 to 66. The female population bet...
# 131  Female age 67 to 69. The female population bet...
# 132  Female age 70 to 74. The female population bet...
# 133  Female age 75 to 79. The female population bet...
# 134  Female age 80 to 84. The female population bet...
# 135  Female age 85 and over. The female population ...
# 136                           White including Hispanic
# 137                           Black including Hispanic
# 138                 American Indian including Hispanic
# 139                           Asian including Hispanic
# 140  Number of workers with a commute between 5 and...
# 141  Number of workers with a commute between 35 an...
# 142  Number of workers with a commute between 40 an...
# 143  Number of workers with a commute between 60 an...
# 144  Number of workers with a commute of more than ...
# 145             Households receiving retirement income
# 146  Population in Armed Forces. The number of peop...
# 147  Population in Civilian Labor Force. The number...
# 148  Employed Population. The number of civilians 1...
# 149
# 150  Population Not in Labor Force. The number of p...
# 151  Population age 16 and over. The number of peop...
# 152  Population in Labor Force. The number of peopl...
# 153                             Asian Men age 45 to 54
# 154                             Asian Men age 55 to 64
# 155                             Black Men age 45 to 54
# 156                             Black Men age 55 to 64
# 157                          Hispanic Men age 45 to 54
# 158                          Hispanic Men age 55 to 64
# 159                             White Men age 45 to 54
# 160                             White Men age 55 to 64
# 161  Population who completed a bachelor's degree. ...
# 162  Population with Bachelors Degree or Higher, Ag...
# 163  Children under 18 Years of Age. The number of ...
# 164  Children under 18 years of age in single femal...
# 165  Commuters by Bus. The number of workers age 16...
# 166  Commuters by Car, Truck, or Van. The number of...
# 167  Commuters by Carpool. The number of workers ag...
# 168  Commuters by Subway or Elevated. The number of...
# 169  Commuters who drove alone. The number of worke...
# 170  Lived in a different house one year ago in a d...
# 171  Lived in a different house one year ago in the...
# 172  Workers employed in firms in agriculture, fore...
# 173  Workers employed in firms in arts, entertainme...
# 174  Workers employed in firms in construction. The...
# 175  Workers employed in firms in educational servi...
# 176  Workers employed in firms in finance, insuranc...
# 177  Workers employed in firms in information. The ...
# 178  Workers employed in firms in manufacturing. Th...
# 179  Workers employed in firms in other services ex...
# 180  Workers employed in firms in public administra...
# 181  Workers employed in firms in retail trade. The...
# 182  Workers employed in firms in professional scie...
# 183  Workers employed in firms in transportation, w...
# 184  Workers employed in firms in wholesale trade. ...
# 185  Households with two female partners. An unmarr...
# 186  Four car households. The number of households ...
# 187  Gini Index. The Gini index, or index of income...
# 188  Population who completed a graduate or profess...
# 189                Population living in group quarters
# 190  Population with high school degree, including ...
# 191  Households on cash public assistance or receiv...
# 192  Students Enrolled in Grades 1 to 4. The total ...
# 193  Students Enrolled in Grades 5 to 8. The total ...
# 194  Students Enrolled in Grades 9 to 12. The total...
# 195  Students Enrolled in School. The total number ...
# 196  Students Enrolled as Undergraduate in College....
# 197  Less than high school graduate. The number of ...
# 198  Men age 45 to 64 who obtained an associate's d...
# 199  Men age 45 to 64 who obtained a bachelor's degree
# 200  Men age 45 to 64 who obtained a graduate or pr...
# 201  Men age 45 to 64 who attained less than a 9th ...
# 202  Men age 45 to 64 who attained between 9th and ...
# 203  Men age 45 to 64 who completed high school or ...
# 204  Men age 45 to 64 who completed some college, n...
# 205  Men age 45 to 64 ("middle aged"). The male pop...
# 206  Households with two male partners. An unmarrie...
# 207  Civilian Employed Population in Management, Bu...
# 208  Workers age 16 and over with no vehicle. All p...
# 209  Car-free households. The number of households ...
# 210  Not a U.S. Citizen Population. The number of p...
# 211  Workers employed in management business scienc...
# 212  Workers employed in natural resources, constru...
# 213  Workers employed in production, transportation...
# 214   Workers employed in sales and office occupations
# 215            Workers employed in service occupations
# 216  One car households. The number of households w...
# 217  Two car households. The number of households w...
# 218  Three car households. The number of households...
# 219  Population age 25 to 64. The number of people ...
# 220  Population for Whom Poverty Status Determined....
# 221  Population 1 year and over. All people, male a...
# 222  Population 3 Years and Over. The total number ...
# 223  Income In The Past 12 Months Below Poverty Lev...
# 224  Civilian Employed Population in Sales and Offi...
# 225  Population who completed some college or obtai...
# 226  Walked to Work. The number of workers age 16 y...
# 227  Worked at Home. The count within a geographica...
# 228  Workers over the Age of 16. The number of peop...
# 229  Population Completed Associate's Degree. The n...
# 230  Population Completed Bachelor's Degree. The nu...
# 231  Population Completed High School. The number o...
# 232  Population completed less than one year of col...
# 233  Population Completed Master's Degree. The numb...
# 234  Population completed more than one year of col...
# 235  Population 25 Years and Over. The number of pe...
# 236  Number of workers with a commute between 35 an...
# 237  Number of workers with a commute of over 60 mi...
# 238  Number of workers with less than 10 minute com...
# 239  Workers age 16 and over who do not work from h...
# 240                               Hispanic of any race
# 241  Population 5 Years and Over. The number of peo...
# 242  Speaks only English at Home. The number of peo...
# 243  Speaks Spanish at Home. The number of people i...
# 244  Speaks Spanish at Home, speaks English less th...
# 245  Population 15 Years and Over. The number of pe...
# 246  Never Married. The number of people in a geogr...
# 247  Currently married. The number of people in a g...
# 248  Married but separated. The number of people in...
# 249  Widowed. The number of people in a geographic ...
# 250  Divorced. The number of people in a geographic...
# 251                                               None

# %% [markdown]
# How many rows in the ACS census data table?

# %%
query = f"""SELECT COUNT(*)
FROM {ACS_DB}.{ACS_TABLE}"""

query_job = client.query(query)

# %%
list(query_job.result())[0][0]
# Out:
# 33120

# %% [markdown]
# How many unique zip codes?

# %%
query = f"""SELECT COUNT(DISTINCT geo_id)
FROM {ACS_DB}.{ACS_TABLE}"""

query_job = client.query(query)

# %%
list(query_job.result())[0][0]
# Out:
# 33120

# %%
# columns to keep from ACS data
ACS_COLS = ['geo_id',
            'total_pop',
            'median_age'
            'housing_units',
            'median_income',
            'housing_units',
            'owner_occupied_housing_units',
            'occupied_housing_units',
            # housing units which will be used to calculate total single-family homes
           'dwellings_1_units_detached',
           'dwellings_1_units_attached',
           'dwellings_2_units',
           'dwellings_3_to_4_units',
           'bachelors_degree_2',
           'different_house_year_ago_different_city',
           'different_house_year_ago_same_city',
           'gini_index']

# %% [markdown]
# # Explore Project Sunroof Data from BigQuery

# %%
query = column_descr_query.format(PSR_DB, PSR_TABLE)
df = pd.read_gbq(query)
df
# Out:
# Downloading: 100%|██████████| 32/32 [00:00<00:00, 242.62rows/s]
#            table_catalog   table_schema                      table_name  \
# 0   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 1   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 2   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 3   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 4   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 5   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 6   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 7   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 8   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 9   bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 10  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 11  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 12  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 13  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 14  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 15  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 16  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 17  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 18  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 19  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 20  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 21  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 22  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 23  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 24  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 25  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 26  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 27  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 28  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 29  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 30  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
# 31  bigquery-public-data  sunroof_solar  solar_potential_by_postal_code
#
#                              column_name  \
# 0                            region_name
# 1                             state_name
# 2                                lat_max
# 3                                lat_min
# 4                                lng_max
# 5                                lng_min
# 6                                lat_avg
# 7                                lng_avg
# 8   yearly_sunlight_kwh_kw_threshold_avg
# 9                        count_qualified
# 10                       percent_covered
# 11                     percent_qualified
# 12                    number_of_panels_n
# 13                    number_of_panels_s
# 14                    number_of_panels_e
# 15                    number_of_panels_w
# 16                    number_of_panels_f
# 17               number_of_panels_median
# 18                number_of_panels_total
# 19                             kw_median
# 20                              kw_total
# 21                 yearly_sunlight_kwh_n
# 22                 yearly_sunlight_kwh_s
# 23                 yearly_sunlight_kwh_e
# 24                 yearly_sunlight_kwh_w
# 25                 yearly_sunlight_kwh_f
# 26            yearly_sunlight_kwh_median
# 27             yearly_sunlight_kwh_total
# 28               install_size_kw_buckets
# 29             carbon_offset_metric_tons
# 30               existing_installs_count
# 31                          center_point
#
#                               field_path  data_type  \
# 0                            region_name     STRING
# 1                             state_name     STRING
# 2                                lat_max    FLOAT64
# 3                                lat_min    FLOAT64
# 4                                lng_max    FLOAT64
# 5                                lng_min    FLOAT64
# 6                                lat_avg    FLOAT64
# 7                                lng_avg    FLOAT64
# 8   yearly_sunlight_kwh_kw_threshold_avg    FLOAT64
# 9                        count_qualified      INT64
# 10                       percent_covered    FLOAT64
# 11                     percent_qualified    FLOAT64
# 12                    number_of_panels_n      INT64
# 13                    number_of_panels_s      INT64
# 14                    number_of_panels_e      INT64
# 15                    number_of_panels_w      INT64
# 16                    number_of_panels_f      INT64
# 17               number_of_panels_median      INT64
# 18                number_of_panels_total      INT64
# 19                             kw_median    FLOAT64
# 20                              kw_total    FLOAT64
# 21                 yearly_sunlight_kwh_n    FLOAT64
# 22                 yearly_sunlight_kwh_s    FLOAT64
# 23                 yearly_sunlight_kwh_e    FLOAT64
# 24                 yearly_sunlight_kwh_w    FLOAT64
# 25                 yearly_sunlight_kwh_f    FLOAT64
# 26            yearly_sunlight_kwh_median    FLOAT64
# 27             yearly_sunlight_kwh_total    FLOAT64
# 28               install_size_kw_buckets     STRING
# 29             carbon_offset_metric_tons    FLOAT64
# 30               existing_installs_count      INT64
# 31                          center_point  GEOGRAPHY
#
#                                           description
# 0                                         Postal Code
# 1            Name of the state containing that region
# 2                    maximum latitude for that region
# 3                    minimum latitude for that region
# 4                   maximum longitude for that region
# 5                   minimum longitude for that region
# 6                    average latitude for that region
# 7                   average longitude for that region
# 8   75% of the optimimum sunlight in the county co...
# 9   # of buildings in Google Maps that are suitabl...
# 10  % of buildings in Google Maps covered by Proje...
# 11  % of buildings covered by Project Sunroof that...
# 12  # of solar panels potential for north-facing r...
# 13  # of solar panels potential for south-facing r...
# 14  # of solar panels potential for east-facing ro...
# 15  # of solar panels potential for west-facing ro...
# 16  # of solar panels potential for flat roof spac...
# 17            # of panels that fit on the median roof
# 18  # of solar panels potential for all roof space...
# 19  kW of solar potential for the median building ...
# 20  # of kW of solar potential for all roof types ...
# 21  total solar energy generation potential for no...
# 22  total solar energy generation potential for so...
# 23  total solar energy generation potential for ea...
# 24  total solar energy generation potential for we...
# 25  total solar energy generation potential for fl...
# 26  kWh/kw/yr for the median roof, in DC (not AC) ...
# 27  total solar energy generation potential for al...
# 28  # of buildings with potential for various inst...
# 29  The potential carbon dioxide abatement of the ...
# 30  # of buildings estimated to have a solar insta...
# 31

# %% [markdown]
# How many rows and unique zip codes here?

# %%
query = f"SELECT COUNT(*) FROM {PSR_DB}.{PSR_TABLE};"
df = pd.read_gbq(query)
df
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  4.54rows/s]
#      f0_
# 0  11516

# %%
query = f"SELECT COUNT(DISTINCT region_name) FROM {PSR_DB}.{PSR_TABLE};"
df = pd.read_gbq(query)
df
# Out:
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  6.47rows/s]
#      f0_
# 0  11512

# %% [markdown]
# Hmm, some duplicates or something?

# %% [markdown]
# # LBNL solar install data

# %%
df1 = pd.read_csv('data/TTS_LBNL_public_file_10-Dec-2019_p1.csv', encoding='latin-1')
# Out:
# /home/nate/anaconda3/envs/dend_capstone/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,2,19,20,32,34,35,36,37,39,40,41,48,49,50,51,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2 = pd.read_csv('data/TTS_LBNL_public_file_10-Dec-2019_p2.csv', encoding='latin-1')
# Out:
# /home/nate/anaconda3/envs/dend_capstone/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,2,19,20,22,24,32,33,34,35,36,37,39,40,41,48,49,50,51,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lbnl_df = pd.concat([df1, df2], axis=0)

# %%
lbnl_df.shape
# Out:
# (1543831, 60)

# %%
# this query takes a while to run, but it ends up being 2.7GB of memory use
lbnl_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1543831 entries, 0 to 843830
# Data columns (total 60 columns):
#  #   Column                                                Non-Null Count    Dtype
# ---  ------                                                --------------    -----
#  0   Data Provider                                         1543831 non-null  object
#  1   System ID (from first Data Provider)                  1543831 non-null  object
#  2   System ID (from second Data Provider, if applicable)  1543831 non-null  object
#  3   System ID (Tracking the Sun)                          1543831 non-null  object
#  4   Installation Date                                     1543831 non-null  object
#  5   System Size                                           1543831 non-null  float64
#  6   Total Installed Price                                 1543831 non-null  float64
#  7   Appraised Value Flag                                  1543831 non-null  bool
#  8   Sales Tax Cost                                        1543831 non-null  float64
#  9   Rebate or Grant                                       1543831 non-null  float64
#  10  Performance-Based Incentive (Annual Payment)          1543831 non-null  float64
#  11  Performance-Based Incentives (Duration)               1543831 non-null  int64
#  12  Feed-in Tariff (Annual Payment)                       1543831 non-null  float64
#  13  Feed-in Tariff (Duration)                             1543831 non-null  int64
#  14  Customer Segment                                      1543831 non-null  object
#  15  New Construction                                      1543831 non-null  int64
#  16  Tracking                                              1543831 non-null  int64
#  17  Ground Mounted                                        1543831 non-null  int64
#  18  Battery System                                        1543831 non-null  int64
#  19  Zip Code                                              1543831 non-null  object
#  20  City                                                  1543831 non-null  object
#  21  State                                                 1543831 non-null  object
#  22  Utility Service Territory                             1543831 non-null  object
#  23  Third-Party Owned                                     1543831 non-null  int64
#  24  Installer Name                                        1543831 non-null  object
#  25  Self-Installed                                        1543831 non-null  int64
#  26  Azimuth #1                                            1543831 non-null  float64
#  27  Azimuth #2                                            1543831 non-null  float64
#  28  Azimuth #3                                            1543831 non-null  float64
#  29  Tilt #1                                               1543831 non-null  float64
#  30  Tilt #2                                               1543831 non-null  int64
#  31  Tilt #3                                               1543831 non-null  int64
#  32  Module Manufacturer #1                                1543831 non-null  object
#  33  Module Model #1                                       1543831 non-null  object
#  34  Module Manufacturer #2                                1543831 non-null  object
#  35  Module Model #2                                       1543831 non-null  object
#  36  Module Manufacturer #3                                1543831 non-null  object
#  37  Module Model #3                                       1543831 non-null  object
#  38  Additional module model                               1543831 non-null  int64
#  39  Module Technology #1                                  1543831 non-null  object
#  40  Module Technology #2                                  1543831 non-null  object
#  41  Module Technology #3                                  1543831 non-null  object
#  42  BIPV Module #1                                        1543831 non-null  int64
#  43  BIPV Module #2                                        1543831 non-null  int64
#  44  BIPV Module #3                                        1543831 non-null  int64
#  45  Module Efficiency #1                                  1543831 non-null  float64
#  46  Module Efficiency #2                                  1543831 non-null  float64
#  47  Module Efficiency #3                                  1543831 non-null  float64
#  48  Inverter Manufacturer #1                              1543831 non-null  object
#  49  Inverter Manufacturer #2                              1543831 non-null  object
#  50  Inverter Manufacturer #3                              1543831 non-null  object
#  51  Inverter Model #1                                     1543831 non-null  object
#  52  Inverter Model #2                                     1543831 non-null  object
#  53  Inverter Model #3                                     1543831 non-null  object
#  54  Microinverter #1                                      1543831 non-null  int64
#  55  Microinverter #2                                      1543831 non-null  int64
#  56  Microinverter #3                                      1543831 non-null  int64
#  57  System Inverter Capacity                              1543831 non-null  float64
#  58  DC Optimizer                                          1543831 non-null  int64
#  59  Inverter Loading Ratio                                1543831 non-null  float64
# dtypes: bool(1), float64(15), int64(18), object(26)
# memory usage: 2.7 GB

# %%
lbnl_df.columns
# Out:
# Index(['Data Provider', 'System ID (from first Data Provider)',
#        'System ID (from second Data Provider, if applicable)',
#        'System ID (Tracking the Sun)', 'Installation Date', 'System Size',
#        'Total Installed Price', 'Appraised Value Flag', 'Sales Tax Cost',
#        'Rebate or Grant', 'Performance-Based Incentive (Annual Payment)',
#        'Performance-Based Incentives (Duration)',
#        'Feed-in Tariff (Annual Payment)', 'Feed-in Tariff (Duration)',
#        'Customer Segment', 'New Construction', 'Tracking', 'Ground Mounted',
#        'Battery System', 'Zip Code', 'City', 'State',
#        'Utility Service Territory', 'Third-Party Owned', 'Installer Name',
#        'Self-Installed', 'Azimuth #1', 'Azimuth #2', 'Azimuth #3', 'Tilt #1',
#        'Tilt #2', 'Tilt #3', 'Module Manufacturer #1', 'Module Model #1',
#        'Module Manufacturer #2', 'Module Model #2', 'Module Manufacturer #3',
#        'Module Model #3', 'Additional module model', 'Module Technology #1',
#        'Module Technology #2', 'Module Technology #3', 'BIPV Module #1',
#        'BIPV Module #2', 'BIPV Module #3', 'Module Efficiency #1',
#        'Module Efficiency #2', 'Module Efficiency #3',
#        'Inverter Manufacturer #1', 'Inverter Manufacturer #2',
#        'Inverter Manufacturer #3', 'Inverter Model #1', 'Inverter Model #2',
#        'Inverter Model #3', 'Microinverter #1', 'Microinverter #2',
#        'Microinverter #3', 'System Inverter Capacity', 'DC Optimizer',
#        'Inverter Loading Ratio'],
#       dtype='object')

# %%
lbnl_df[['Module Manufacturer #1', 'Module Manufacturer #2', 'Module Manufacturer #3']].head()
# Out:
#   Module Manufacturer #1 Module Manufacturer #2 Module Manufacturer #3
# 0                  Sharp                  -9999                  -9999
# 1                  Sharp                  -9999                  -9999
# 2                  Sharp                  -9999                  -9999
# 3                  Sharp                  -9999                  -9999
# 4                  Sharp                  -9999                  -9999

# %% [markdown]
# How many residential installs in the data?

# %%
lbnl_df[lbnl_df['Customer Segment'] == 'RES'].shape
# Out:
# (1456225, 60)

# %% [markdown]
# Who are the top installers?
#
# Note: -9999 is missing data.

# %%
lbnl_df['Installer Name'].value_counts()
# Out:
# solarcity                                                                                      283374
# -9999                                                                                           92562
# vivint                                                                                          90032
# sunrun                                                                                          54550
# -9999                                                                                           49152
# sunpower                                                                                        40587
# trinity                                                                                         32865
# sungevity                                                                                       24227
# petersen dean                                                                                   22466
# verengo                                                                                         20125
# rec solar                                                                                       19545
# titan solar power                                                                               12687
# real good                                                                                       12339
# Horizon Solar Power                                                                             12016
# semper solar                                                                                     9920
# grid alternative                                                                                 9918
# nb baker                                                                                         9325
# leonard roofing                                                                                  9080
# nrg                                                                                              8631
# sullivan solar power                                                                             7197
# astrum solar                                                                                     6831
# american solar direct                                                                            6408
# roof diagnostic                                                                                  6379
# solciu                                                                                           5837
# future energy                                                                                    5463
# pro customer solar                                                                               5362
# 1st light                                                                                        5128
# self                                                                                             4914
# sun valley solar                                                                                 4912
# American Solar Electric Inc                                                                      4882
# infinity                                                                                         4625
# complete solar                                                                                   4434
# ark construction                                                                                 4059
# a1 solar power                                                                                   3703
# solarmax renewable energy provider                                                               3672
# stellar solar                                                                                    3664
# all season                                                                                       3653
# solar united network                                                                             3506
# sun common                                                                                       3454
# solar service center                                                                             3370
# la solar                                                                                         3313
# west coast                                                                                       3207
# renova                                                                                           3172
# freedom solar                                                                                    3150
# calfornia solar                                                                                  3144
# smart energy                                                                                     3100
# nexu energy                                                                                      2934
# sun crest                                                                                        2915
# sun solar energy                                                                                 2913
# south west sun solar                                                                             2890
# v3 electric                                                                                      2867
# akeena                                                                                           2835
# helio power                                                                                      2776
# arcadia solar                                                                                    2767
# mcferrin and                                                                                     2672
# harmon                                                                                           2667
# solar top                                                                                        2631
# alternative energy                                                                               2525
# code green                                                                                       2516
# galko                                                                                            2493
# next step living                                                                                 2483
# sun gate energy                                                                                  2482
# bland solar air                                                                                  2461
# west haven                                                                                       2325
# gci solar                                                                                        2301
# sun logic                                                                                        2286
# quality home                                                                                     2222
# sea bright                                                                                       2192
# sierra pacfic home comfort                                                                       2172
# smart solar marketing                                                                            2156
# clean                                                                                            2108
# sun street                                                                                       2095
# fidelity home energy                                                                             2018
# arizona solar solution                                                                           1983
# maier engineering                                                                                1933
# advanced solar and electric                                                                      1917
# level solar                                                                                      1910
# northeast solar                                                                                  1901
# elevation solar                                                                                  1889
# solar liberty energy system                                                                      1871
# solar tech                                                                                       1848
# streamline solar power                                                                           1848
# technician for sustainability                                                                    1827
# posigen                                                                                          1813
# borrego solar                                                                                    1809
# rcl enterprise                                                                                   1801
# hooked on solar                                                                                  1795
# freedom forever                                                                                  1778
# burke electric contractor                                                                        1764
# cobalt power                                                                                     1748
# asi hasting                                                                                      1737
# arizona solar concept                                                                            1720
# vision                                                                                           1689
# quick system                                                                                     1688
# smart energy usa                                                                                 1681
# high definition solar                                                                            1675
# elite electric                                                                                   1661
# acro energy                                                                                      1657
# sunlight solar                                                                                   1653
# ted mount                                                                                        1646
# hawaii environmental holding                                                                     1646
# bright planet solar                                                                              1632
# solar west electric                                                                              1626
# solaire energy                                                                                   1620
# sunation solar system                                                                            1583
# revision                                                                                         1569
# suntime energy builder                                                                           1566
# energu remodeling                                                                                1558
# solarcraft                                                                                       1555
# sunbug solar                                                                                     1550
# sun line energy                                                                                  1532
# energy enterprise usa                                                                            1520
# alltera enviromental                                                                             1508
# green convergence                                                                                1500
# positive energy                                                                                  1490
# solar universe                                                                                   1467
# consolidated solar technology                                                                    1442
# solarflair                                                                                       1427
# boston solar                                                                                     1420
# sun ny energy                                                                                    1413
# arise solar                                                                                      1404
# apex solar power                                                                                 1390
# lighthouse solar austin                                                                          1384
# luminalt energy                                                                                  1383
# spg solar                                                                                        1383
# planet solar                                                                                     1370
# american array solar                                                                             1355
# valley unique                                                                                    1354
# ros solar                                                                                        1352
# esmay electric                                                                                   1350
# revolve                                                                                          1346
# quality firsi home improvement                                                                   1305
# advanced solar electric                                                                          1303
# renewable energy                                                                                 1298
# sunergy                                                                                          1294
# global resource option                                                                           1288
# next energy                                                                                      1283
# sun light & power                                                                                1281
# mohr power solar                                                                                 1276
# syntrol                                                                                          1251
# solar one                                                                                        1249
# sun pro solar                                                                                    1242
# energy concept                                                                                   1216
# c tec solar                                                                                      1215
# preci solar                                                                                      1214
# bay area solar soltion                                                                           1207
# pv squared pioneer valleyphotovoltaic                                                            1193
# sun first                                                                                        1191
# adr electric                                                                                     1187
# american                                                                                         1173
# salt river                                                                                       1173
# paramount energy                                                                                 1172
# unleaded design                                                                                  1163
# diablo solar                                                                                     1145
# cam solar                                                                                        1144
# argent solar                                                                                     1126
# solar phonic                                                                                     1124
# hot purple                                                                                       1119
# cosmic solar                                                                                     1104
# valleysolar                                                                                      1095
# am sun                                                                                           1091
# pa lomar solar ltd                                                                               1090
# jp son                                                                                           1074
# enegy saving pro                                                                                 1070
# stout burg                                                                                       1067
# syntrol plumbing heating air                                                                     1064
# hudson solar                                                                                     1063
# 360 solar                                                                                        1049
# affordable solar                                                                                 1047
# tm solar                                                                                         1037
# milholland electric                                                                              1036
# sky etch solar                                                                                   1035
# power light                                                                                      1008
# fralick home                                                                                      989
# sun bee                                                                                           974
# monolith solar associate                                                                          972
# all energy solar                                                                                  969
# phoenix solar                                                                                     967
# new england clean energy                                                                          964
# endless mountain solar service                                                                    949
# sun spot solar energy system                                                                      949
# kasselman solar                                                                                   943
# herca solar                                                                                       941
# eru builder                                                                                       941
# advanced solar                                                                                    937
# aco energy                                                                                        931
# solar solution az                                                                                 931
# the kalman company                                                                                931
# peak power                                                                                        928
# ies residential                                                                                   924
# zing solar                                                                                        916
# solar network                                                                                     912
# nova west solar                                                                                   905
# kopp electric                                                                                     901
# keuetzfeldt construction                                                                          892
# kuykendall                                                                                        891
# suntime                                                                                           877
# pell solar                                                                                        875
# renovu energy                                                                                     874
# green logic                                                                                       870
# solar optimum                                                                                     863
# capital city solar                                                                                836
# empower ces                                                                                       836
# kilowatt system                                                                                   829
# sun fusion solar                                                                                  827
# kurio                                                                                             824
# so cal solar                                                                                      817
# lifestyle solar                                                                                   817
# clean energy                                                                                      817
# reliable power service                                                                            817
# south texas solar                                                                                 816
# new day solar                                                                                     813
# magic sun solar                                                                                   810
# green power energy                                                                                805
# green nrg                                                                                         793
# simply solar                                                                                      793
# sky line                                                                                          788
# home energy                                                                                       767
# revco solar                                                                                       765
# zero energy assocaite                                                                             764
# granite state solar                                                                               759
# sun vest                                                                                          754
# sun light                                                                                         753
# electric are                                                                                      750
# carlson solar                                                                                     744
# solar unive                                                                                       742
# longhorn solar                                                                                    738
# burro electric                                                                                    738
# sky high energy                                                                                   734
# sun up zero down                                                                                  727
# barne solar                                                                                       724
# ameco                                                                                             724
# gira                                                                                              722
# harvest power                                                                                     720
# antonio zullo electric                                                                            720
# sun lux                                                                                           720
# net zero                                                                                          717
# summerwind solar                                                                                  712
# pro custom                                                                                        700
# sun harvest                                                                                       696
# light house                                                                                       691
# amergy                                                                                            689
# occidental power                                                                                  687
# unlimied energy                                                                                   686
# premier power renewable energy                                                                    685
# sun wize                                                                                          684
# the remodelor                                                                                     682
# sunnova                                                                                           677
# long island power solution                                                                        671
# singshot power                                                                                    665
# restart solar                                                                                     664
# sun ray solar                                                                                     663
# jaj roofin                                                                                        659
# divine power usa                                                                                  656
# gocontractor                                                                                      653
# demarse electric                                                                                  652
# fluent solar                                                                                      648
# precis development                                                                                647
# power house                                                                                       632
# chico electric                                                                                    630
# sunwork renewable energy project                                                                  627
# solar max renewable                                                                               626
# american solar partner                                                                            625
# power lution                                                                                      623
# stealth solar                                                                                     620
# pro gressive energy                                                                               619
# corbin solar solution                                                                             607
# spectrum energy                                                                                   605
# equisolar                                                                                         605
# earthlight technology                                                                             605
# blue selenium solar                                                                               605
# complex2simple                                                                                    602
# secure roofing solar                                                                              599
# premier solar                                                                                     598
# all on elecric                                                                                    596
# belcon development                                                                                589
# solar 360 building                                                                                589
# reliable power solar                                                                              589
# valleypacific builder                                                                             587
# cotuit solar                                                                                      586
# geogenix                                                                                          579
# aegi electric system                                                                              573
# new power                                                                                         571
# freedom solar power                                                                               568
# green hill remodeing                                                                              555
# doinald p dick air conditioning                                                                   553
# high light                                                                                        552
# brite energy                                                                                      551
# bmc solar                                                                                         551
# phoenix energy                                                                                    549
# pacific stonegate                                                                                 548
# pure energy                                                                                       547
# designer s way                                                                                    547
# pacific sky solar                                                                                 542
# sun craft                                                                                         538
# jamar power system                                                                                535
# pro voltz                                                                                         532
# natural power source                                                                              532
# the solar center                                                                                  530
# mc wire electric                                                                                  528
# solar co                                                                                          527
# horizon energy system                                                                             526
# regrid power                                                                                      524
# befree green energy                                                                               517
# citadel roofing                                                                                   514
# e2 solar                                                                                          505
# quantum solar                                                                                     503
# energy plu air                                                                                    501
# permacity                                                                                         500
# sun gate                                                                                          499
# royal air                                                                                         498
# complete solar solution of california                                                             497
# sunrise solar                                                                                     497
# built green california                                                                            496
# gayler                                                                                            495
# poco solar energy                                                                                 492
# nj solar power                                                                                    491
# sol tek                                                                                           490
# baker solar electric                                                                              488
# texas solar power company                                                                         487
# circular energy                                                                                   485
# arise construction                                                                                480
# cir electric construction                                                                         480
# zero energy                                                                                       477
# golden gate                                                                                       476
# bright life solar                                                                                 474
# second generation energy                                                                          473
# plan igt solar                                                                                    468
# best solar power                                                                                  468
# haskin electric                                                                                   467
# geoscape solar                                                                                    465
# yuma solar                                                                                        459
# brightergy                                                                                        458
# northern pacific power                                                                            454
# sierra solar                                                                                      454
# well solar                                                                                        453
# cny solar                                                                                         451
# austin electric                                                                                   447
# sonray                                                                                            445
# mauzy mechanical                                                                                  444
# ion solar                                                                                         443
# ge energy usa                                                                                     441
# california premier                                                                                439
# sun belt solar                                                                                    439
# solar home                                                                                        438
# green tech solution                                                                               438
# heritage solar                                                                                    437
# sharpe solar energy                                                                               436
# reliable remodeler                                                                                435
# encon                                                                                             434
# alternative power                                                                                 434
# ground up builder                                                                                 433
# frase electric                                                                                    433
# straight up solar                                                                                 431
# all bay solar                                                                                     428
# verengo solar plu                                                                                 427
# solex electronic                                                                                  424
# sun trek                                                                                          422
# empire solar                                                                                      421
# rooftop solar                                                                                     421
# etm solar work                                                                                    418
# amabassador energy                                                                                418
# the green store                                                                                   418
# solect energy development                                                                         417
# solar source                                                                                      417
# sebastopol heat cool                                                                              416
# basad construction                                                                                413
# smart                                                                                             408
# you save green                                                                                    408
# unleash solar                                                                                     405
# sun nymac                                                                                         404
# as electric                                                                                       404
# pro gressive power                                                                                403
# bay area system solution                                                                          402
# gnrg                                                                                              400
# sky line energy saer                                                                              399
# brooklyn solar work                                                                               398
# bell electric                                                                                     397
# venture home solar                                                                                393
# solar watt                                                                                        393
# emc builder                                                                                       392
# cooperative community energy                                                                      392
# new york state solar farm                                                                         390
# mas renewable                                                                                     388
# advanced improvement                                                                              388
# asi heating air                                                                                   388
# on eroof energy                                                                                   388
# solar electric texa                                                                               386
# ilum slar                                                                                         385
# best energy power                                                                                 384
# solar universe san marco                                                                          383
# perfectpower                                                                                      383
# aztec                                                                                             383
# halco renewable energy                                                                            382
# la power center                                                                                   382
# free energy                                                                                       382
# qaulity home renovator                                                                            381
# native                                                                                            379
# jp electric                                                                                       377
# a1 sun                                                                                            376
# cmh partner                                                                                       375
# eriksson                                                                                          374
# az sun service                                                                                    374
# titan construction                                                                                373
# eznergy                                                                                           370
# rancho solar                                                                                      368
# option one                                                                                        367
# all solar                                                                                         366
# custom solar                                                                                      364
# synergy solar electric al system                                                                  364
# levi builder                                                                                      364
# solar revolution                                                                                  362
# isolar universe brientwood                                                                        362
# pacific rim                                                                                       361
# green street power partner                                                                        360
# sol fusion                                                                                        360
# alba energy                                                                                       359
# black platinum solar electric                                                                     359
# south ern california home improvement cen                                                         358
# ion developer                                                                                     355
# south west                                                                                        354
# green spring                                                                                      353
# scudder roofing sun energy                                                                        353
# mac electric                                                                                      352
# geopeak energy                                                                                    352
# contact elecric                                                                                   349
# dc                                                                                                348
# milligan electric                                                                                 346
# scott william                                                                                     346
# solar construction serviceing center                                                              346
# pacific blue                                                                                      346
# smart solar of southern california                                                                345
# ace residential                                                                                   345
# bap power                                                                                         344
# solar five                                                                                        344
# south ern california solar                                                                        342
# 4th day energy                                                                                    340
# solar rising                                                                                      340
# goo                                                                                               340
# ad energy                                                                                         339
# sharp electronic                                                                                  336
# aes                                                                                               336
# us green energy                                                                                   335
# sunpower system richmond                                                                          335
# infinity solar                                                                                    334
# clary solar                                                                                       333
# meridian                                                                                          332
# alteri renewable                                                                                  331
# pac solar                                                                                         329
# referral design                                                                                   329
# secure home improvement                                                                           329
# velocity solar power                                                                              329
# arizona energy pro                                                                                328
# south mountain company                                                                            326
# paul j cazeault amp son                                                                           326
# everyday communication                                                                            325
# sustainable                                                                                       325
# energy rennovation center                                                                         325
# integrity                                                                                         324
# dependable solar product                                                                          324
# microgrid energy residential                                                                      324
# gaia energy system                                                                                323
# bay area solar                                                                                    322
# arch electric                                                                                     322
# brightstar solar                                                                                  321
# desert solar                                                                                      320
# urban energy                                                                                      320
# lidini                                                                                            319
# brower emchanical                                                                                 319
# jkb development                                                                                   319
# ...
# grid alternative org                                                                                1
# seek solar energy                                                                                   1
# cunningham parri construction                                                                       1
# true light electric                                                                                 1
# kelly nixon construction                                                                            1
# build allen                                                                                         1
# eco green contractor staten                                                                         1
# spic                                                                                                1
# mr cool 4 ac                                                                                        1
# jesse knolle electric                                                                               1
# mark balken construction                                                                            1
# angres construction                                                                                 1
# pat munger construction company                                                                     1
# mister tile                                                                                         1
# sun work energy alternative vince gallo                                                             1
# pinnacle property                                                                                   1
# verified bysteven todorov                                                                           1
# a maxey energy ii                                                                                   1
# wagner energy solution                                                                              1
# fortune energy                                                                                      1
# staten solar corparation                                                                            1
# intech mechanical                                                                                   1
# scharn industry                                                                                     1
# wayne hinkson                                                                                       1
# touchstone builder                                                                                  1
# jarren welch                                                                                        1
# metro solar design installation                                                                     1
# advanced remodeling                                                                                 1
# kms wood design                                                                                     1
# bb engineering                                                                                      1
# kwatt solar solution                                                                                1
# chri mcdonough                                                                                      1
# fire wire system                                                                                    1
# pride building service                                                                              1
# zachariah a chaffee                                                                                 1
# pasamonte design construction                                                                       1
# sun wave solar                                                                                      1
# paul builder                                                                                        1
# brazen investment                                                                                   1
# avco electric service alan vanalstine                                                               1
# nova west builder                                                                                   1
# richard glveck                                                                                      1
# sun water solar                                                                                     1
# castle craftsmen                                                                                    1
# pterodactyl construction company                                                                    1
# osborne s construction                                                                              1
# imx                                                                                                 1
# aaaplanner builder                                                                                  1
# helipower                                                                                           1
# gl daniel construction                                                                              1
# south ern california home impro                                                                     1
# norseman electric                                                                                   1
# aleco                                                                                               1
# solamerican energy                                                                                  1
# gnrysolar                                                                                           1
# benson son electric                                                                                 1
# premise                                                                                             1
# marekpokora                                                                                         1
# ronald stinson ia only                                                                              1
# terry skate                                                                                         1
# dean m electric                                                                                     1
# steve mayer ia only                                                                                 1
# green o s electric construction                                                                     1
# california solar elec                                                                               1
# lc contracting                                                                                      1
# residential                                                                                         1
# stevegriffinconstruction com                                                                        1
# mel dion cardinal                                                                                   1
# giant electric                                                                                      1
# bentley global associate                                                                            1
# joseph urban                                                                                        1
# electric maintenance service                                                                        1
# ld strobel                                                                                          1
# atran electric technology                                                                           1
# apple home development                                                                              1
# a1 contra                                                                                           1
# south ern sky renewable energy rhode island                                                         1
# transtech technology                                                                                1
# csr eznergy                                                                                         1
# accessibility design construction                                                                   1
# san diego mechatronic                                                                               1
# valencia electric                                                                                   1
# nevada alpha technology                                                                             1
# richard gtoeek                                                                                      1
# eck doerry ia only                                                                                  1
# ideal solar construction company                                                                    1
# pruden roofing                                                                                      1
# la la s ignacio                                                                                     1
# legacy roofing water proofing                                                                       1
# sprint remodeling design                                                                            1
# clean power finance                                                                                 1
# white barn gce                                                                                      1
# usmc                                                                                                1
# jack lemler plast ering                                                                             1
# kin dunbar son s construction                                                                       1
# alderete solar                                                                                      1
# eric finney                                                                                         1
# rolf halden ia only                                                                                 1
# anderson pacific                                                                                    1
# designer engineering contracting                                                                    1
# etcheverry electric                                                                                 1
# roger miller current integration                                                                    1
# ksp solar                                                                                           1
# pave tech                                                                                           1
# ascendent energy company                                                                            1
# rich river                                                                                          1
# phoenix energy fulfillment                                                                          1
# sanua cochrane                                                                                      1
# bruce follansbee diane tissot                                                                       1
# michael connolly                                                                                    1
# ownsolar                                                                                            1
# wizer electric                                                                                      1
# whelen electric                                                                                     1
# quality building remodeling                                                                         1
# rj dronberoer                                                                                       1
# trejo refrigeration electric                                                                        1
# jame rericha                                                                                        1
# a benchmark energy solution                                                                         1
# timothy weible ia only                                                                              1
# vaverne son                                                                                         1
# upgrade electric                                                                                    1
# erin noble                                                                                          1
# nibbi brother associate                                                                             1
# island view electric                                                                                1
# robert rimstad                                                                                      1
# la bron taylor jr                                                                                   1
# cano garcia                                                                                         1
# a2e affordable alternative energy                                                                   1
# mcferrin compant                                                                                    1
# geotran                                                                                             1
# thermal design                                                                                      1
# swinerton renewable energy                                                                          1
# steve triolo electric                                                                               1
# chuck lidberg mfg home                                                                              1
# burn elect                                                                                          1
# sun view vineyard of ca                                                                             1
# archon electric                                                                                     1
# adlaw power                                                                                         1
# mr craig m maxwell                                                                                  1
# sharpe construction company                                                                         1
# christopher de leon                                                                                 1
# suntime eenrgy                                                                                      1
# hunter construction                                                                                 1
# unknow installed prior to purchase of property                                                      1
# re comm electric                                                                                    1
# powehouse system                                                                                    1
# ec constructor                                                                                      1
# wallace smith                                                                                       1
# prevailing wind                                                                                     1
# terry hartill                                                                                       1
# kuykendall soalr                                                                                    1
# mr yosef loschak                                                                                    1
# goldstar                                                                                            1
# smit heatnig airable electric                                                                       1
# real good solar regrid                                                                              1
# manley                                                                                              1
# Name: Installer Name, dtype: int64

# %% [markdown]
# How many self-installed?

# %%
lbnl_df['Self-Installed'].value_counts()
# Out:
#  0       1261516
# -9999     260025
#  1         22290
# Name: Self-Installed, dtype: int64

# %% [markdown]
# How many datapoints missing self-installed and installer?

# %%
lbnl_df[(lbnl_df['Self-Installed'] == -9999) & (lbnl_df['Installer Name'] == -9999)].shape
# Out:
# (49152, 60)

# %% [markdown]
# # EIA-861 Report
#
# Energy prices and amount sold to residential customers.

# %%
eia861_df = pd.read_excel('data/Sales_Ult_Cust_2018.xlsx')

# %%
eia861_df.shape
# Out:
# (3436, 24)

# %%
eia861_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436 entries, 0 to 3435
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Utility Characteristics  3435 non-null   object
#  1   Unnamed: 1               3434 non-null   object
#  2   Unnamed: 2               3434 non-null   object
#  3   Unnamed: 3               3434 non-null   object
#  4   Unnamed: 4               3434 non-null   object
#  5   Unnamed: 5               3434 non-null   object
#  6   Unnamed: 6               3434 non-null   object
#  7   Unnamed: 7               3275 non-null   object
#  8   Unnamed: 8               3403 non-null   object
#  9   RESIDENTIAL              3435 non-null   object
#  10  Unnamed: 10              3435 non-null   object
#  11  Unnamed: 11              3435 non-null   object
#  12  COMMERCIAL               3435 non-null   object
#  13  Unnamed: 13              3435 non-null   object
#  14  Unnamed: 14              3435 non-null   object
#  15  INDUSTRIAL               3435 non-null   object
#  16  Unnamed: 16              3435 non-null   object
#  17  Unnamed: 17              3435 non-null   object
#  18  TRANSPORTATION           3435 non-null   object
#  19  Unnamed: 19              3435 non-null   object
#  20  Unnamed: 20              3435 non-null   object
#  21  TOTAL                    3435 non-null   object
#  22  Unnamed: 22              3435 non-null   object
#  23  Unnamed: 23              3435 non-null   object
# dtypes: object(24)
# memory usage: 3.6 MB

# %% [markdown]
# # EIA IOU rates with zipcodes

# %%
iou_df = pd.read_csv('data/iouzipcodes2017.csv')
noniou_df = pd.read_csv('data/noniouzipcodes2017.csv')
eia_zipcode_df = pd.concat([iou_df, noniou_df], axis=0)
eia_zipcode_df.shape
# Out:
# (86672, 9)

# %%
eia_zipcode_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86672 entries, 0 to 34073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   zip           86672 non-null  int64
#  1   eiaid         86672 non-null  int64
#  2   utility_name  86672 non-null  object
#  3   state         86672 non-null  object
#  4   service_type  86672 non-null  object
#  5   ownership     86672 non-null  object
#  6   comm_rate     86672 non-null  float64
#  7   ind_rate      86672 non-null  float64
#  8   res_rate      86672 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 26.7 MB
